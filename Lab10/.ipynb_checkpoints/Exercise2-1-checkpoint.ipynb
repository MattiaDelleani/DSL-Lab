# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./dataset/2D_gauss_clusters.txt", sep = ",")

# %%
plt.figure(figsize=[8,8])
plt.scatter(df.iloc[:,0], df.iloc[:,1], s = 1, marker=".")

# %% [markdown]
# K-Means works well with globular shapes and with dataset homogeneus in desnity and size. It works bad with noise and outliers. Here we have quite good globular shapes but we have different densities. Maybe DBSCAN will work better.

# %%
sample = df.sample(n=5, random_state = 42 )
len(sample)
for v, idx in zip(sample.values, sample.index):
    print(v ," - ", idx)
    
for col in sample.columns:
    sample[col] = 0
    print("1")
sample
# Out:
# [819347 262933]  -  1501
# [571086 725107]  -  2586
# [640485 708409]  -  2653
# [552519 443109]  -  1055
# [289447 672315]  -  705
# 1
# 1
#       x  y
# 1501  0  0
# 2586  0  0
# 2653  0  0
# 1055  0  0
# 705   0  0

# %%
class KMeans:
    def __init__(self, n_clusters, max_iter=100):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.centroids = None
        self.labels = None
    
    def fit_predict(self, X):
        """Run the K-means clustering on X.
        :param X: input data points, array, shape = (N,C).
        :return: labels : array, shape = N.
        """
        self.centroids = X.sample(n = self.n_clusters, random_state = 42)
        self.labels = list(range(0, len(self.centroids)))
        
        distance = pd.DataFrame(np.zeros((X.shape[0], len(self.labels))))
        
        #for i in range(self.max_iter):
            
        for col, idx in zip(distance.columns, self.centroids.index):
            distance[col] = np.array([np.linalg.norm(v - X.values[idx]) for v in X.values])
            
        #minimo = risultato.min(axis=1)
        nearest = risultato.values.argmin(axis=1)
        
        plt.scatter(X.iloc[:,0],X.iloc[:,1], c= nearest, cmap = "Set3")
        return distance

# %%
#prova = KMeans(10)
#risultato = prova.fit_predict(df)
#minimo = risultato.values.argmin(axis=1)
#prova = pd.DataFrame(np.zeros((risultato.shape[0], risultato.shape[1]) ))
#risultato.iloc[0,:] == 2
#res = np.array([True]*3)
#minimo

# %%
df.iloc[:,:]['x']
# Out:
# 0       845753
# 1       812954
# 2       868217
# 3       920248
# 4       841621
#          ...
# 4995    633450
# 4996    662080
# 4997    706472
# 4998    659128
# 4999    665898
# Name: x, Length: 5000, dtype: int64

# %%
type(df.iloc[:,:]['x'])
# Out:
# pandas.core.series.Series

# %%
values = df.values
res = np.array([np.linalg.norm(v - values[0]) for v in values])

# %%
res.argsort()
# Out:
# array([   0,  229,  238, ..., 3386, 3349, 3404], dtype=int64)

# %%
 df.values[0]
# Out:
# array([845753, 636607], dtype=int64)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters= 10, random_state=42).fit_predict(df)

# %%
kmeans
# Out:
# array([1, 1, 1, ..., 5, 5, 5])

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1], c= kmeans, cmap = "Set3")

# %%
from sklearn.metrics import silhouette_score, silhouette_samples

# %%
sil = silhouette_score(df, kmeans)

# %%
(sil)
# Out:
# 0.5182509292094666

# %%
sil_samples= silhouette_samples(df, kmeans)

# %%
sil_samples.mean()
# Out:
# 0.5182509292094666
