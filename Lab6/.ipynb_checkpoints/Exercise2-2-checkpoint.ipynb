# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'..\dataset\2d-synthetic.csv')
df
# Out:
#            x0        x1  label
# 0    9.833469  0.319565      0
# 1    1.801045  8.705072      0
# 2    4.423918  3.488906      1
# 3    0.280730  2.689037      1
# 4    5.999494  9.167512      0
# ..        ...       ...    ...
# 495  4.995458  8.437083      0
# 496  6.636632  9.931535      0
# 497  6.373259  8.098388      0
# 498  1.230331  7.169844      1
# 499  6.070298  0.741824      1
#
# [500 rows x 3 columns]

# %%
colors = ['blue', 'red']
grouped = df.groupby('label')

plt.scatter(df[df['label'] == 0]['x0'], df[df['label'] == 0]['x1'], color ="red", label = "0", marker = ".")
plt.scatter(df[df['label'] == 1]['x0'], df[df['label'] == 1]['x1'], color ="blue", label = "1", marker = "*")

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(df[['x0', 'x1']], df['label'])
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Tree Visualization

# %%
from sklearn.tree import export_graphviz
dot_code = export_graphviz(clf, feature_names=['x0','x1'])
#print(dot_code)

img = plt.imread(r"C:\Users\matti\Desktop\Magistrale\Data science lab\Labs\DSL-Lab\Lab6\2-2-Tree.PNG")
plt.figure(figsize = [13,13])
plt.imshow(img)
plt.show()

# %% [markdown]
# As we can see in the graph the Tree is too depth, so it can distinguish too many classes so it's fully depth. We know that there are only two different classes so it could be a good idea to stop it at step 1 where there are 2 leaf nodes, beacause they are quite homogeneneus 198/67, 192/42. So we can operate with a pre-pruinig, stop before it grows too much, or post-pruining

# %% [markdown]
# ## 2.2.3

# %%
clf2 = DecisionTreeClassifier(max_depth=2)
clf2.fit(df[['x0', 'x1']], df['label'])
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
dot_code = export_graphviz(clf2, feature_names=['x0','x1'])
#print(dot_code)

img = plt.imread(r"C:\Users\matti\Desktop\Magistrale\Data science lab\Labs\DSL-Lab\Lab6\2-2-Tree2.PNG")
plt.figure(figsize = [13,13])
plt.imshow(img)
plt.show()

# %%
clf2.tree_.feature
# Out:
# array([ 0,  1, -2, -2,  1, -2, -2], dtype=int64)

# %%
clf.tree_.feature
# Out:
# array([ 0,  1,  1,  0, -2,  1, -2, -2,  0, -2, -2,  0,  1,  0, -2,  1, -2,
#        -2,  0,  1, -2, -2, -2,  0,  1,  0, -2,  0, -2, -2,  1,  0, -2, -2,
#        -2, -2,  1,  0,  1, -2,  0, -2, -2, -2,  1,  0, -2, -2, -2],
#       dtype=int64)

# %%
#dont understand the meaning
